# %%
import pandas as pd

df=pd.read_csv('housing_price_dataset.csv')

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
import numpy as np
import pandas as pd

# %%
df.isnull()
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt  Price
# 0           False     False      False         False      False  False
# 1           False     False      False         False      False  False
# 2           False     False      False         False      False  False
# 3           False     False      False         False      False  False
# 4           False     False      False         False      False  False
# ...           ...       ...        ...           ...        ...    ...
# 49995       False     False      False         False      False  False
# 49996       False     False      False         False      False  False
# 49997       False     False      False         False      False  False
# 49998       False     False      False         False      False  False
# 49999       False     False      False         False      False  False
#
# [50000 rows x 6 columns]

# %%
df.dropna()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
import matplotlib.pyplot as plt
import pandas as pd

new_df = pd.DataFrame({
    'SquareFeet': [2126, 22459, 1860, 2294, 2130],
    'Bedrooms': [4, 3, 2, 2, 5],
    'Bathrooms': [1, 2, 1, 1, 2],
    'Neighborhood': ['Rural', 'Rural', 'Suburb', 'Urban', 'Suburb'],
    'YearBuilt': [1969, 1980, 1970, 1996, 2001],
    'Price': [215355.283618, 195014.221626, 306891.012076, 206786.787153, 272436.239065]
})

columns_to_plot = ['SquareFeet', 'Bedrooms', 'Bathrooms', 'YearBuilt', 'Price']


plt.plot(new_df[columns_to_plot])
plt.legend(columns_to_plot)  
plt.title("House Pricing ")
plt.show()

plt.plot(new_df['SquareFeet'],new_df['Price'])
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.title('Price vs Square Feet')
plt.legend(['Price vs Square Feet'])
plt.show()

new_df.boxplot(column='Price')
plt.title('Boxplot of Price')
plt.show()

# %%
# !pip install sweetviz
# Out:
# ...
#   Obtaining dependency information for sweetviz from https://files.pythonhosted.org/packages/89/50/8d3f7ca820267a38b42c64778db0f186d85cec6e3f0c5210eab9c16e783f/sweetviz-2.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for importlib-resources>=1.2.0 from https://files.pythonhosted.org/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB 660.6 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/15.1 MB 656.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/15.1 MB 655.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/15.1 MB 726.2 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/15.1 MB 607.9 kB/s eta 0:00:25
#    ---------------------------------------- 0.2/15.1 MB 655.4 kB/s eta 0:00:23
# ...

# %%
import pandas as pd
import sweetviz 
df=pd.read_csv('housing_price_dataset.csv')

# %%
my_report=sweetviz.analyze([df,'Housing price'],target_feat='Price')
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
my_report.show_html('Report.html')
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
print(df.columns)
# Out:
# Index(['SquareFeet', 'Bedrooms', 'Bathrooms', 'Neighborhood', 'YearBuilt',
#        'Price'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 5, figsize=(20, 3))  
sns.scatterplot(x=df['SquareFeet'], y=df['Price'], ax=ax[0])
sns.scatterplot(x=df['Bedrooms'], y=df['Price'], ax=ax[1])
sns.scatterplot(x=df['Bathrooms'], y=df['Price'], ax=ax[2])
sns.scatterplot(x=df['Neighborhood'], y=df['Price'], ax=ax[3])
sns.scatterplot(x=df['YearBuilt'], y=df['Price'], ax=ax[4])
plt.show()

# %%
sns.heatmap(df.corr(), annot=True);

# %%
from sklearn.model_selection import train_test_split
 
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
 
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=0)

# %%
x_train
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt
# 17967        2960         5          2       Suburb       1992
# 32391        2511         4          2        Rural       1983
# 9341         2851         5          2        Urban       1976
# 7929         1320         4          1        Urban       1980
# 46544        1466         5          2        Urban       1968
# ...           ...       ...        ...          ...        ...
# 21243        1673         2          2        Rural       2020
# 45891        1336         3          2        Rural       1952
# 42613        2001         5          1       Suburb       1987
# 43567        2605         4          1        Urban       1955
# 2732         1575         5          3        Rural       1966
#
# [35000 rows x 5 columns]

# %%
y_train
# Out:
# 24677    296547.379489
# 42051    187246.960085
# 8844     216333.680683
# 45734    236212.812562
# 40428    162009.133639
#              ...
# 21243    201321.465506
# 45891    155134.446426
# 42613    317759.367208
# 43567    295820.866145
# 2732     232085.490216
# Name: Price, Length: 47500, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

x = df[['SquareFeet', 'Bedrooms', 'Bathrooms', 'Neighborhood', 'YearBuilt']]
y = df['Price']

label_encoder = LabelEncoder()
x_train['Neighborhood'] = label_encoder.fit_transform(x_train['Neighborhood'])
x_test['Neighborhood'] = label_encoder.transform(x_test['Neighborhood'])

liregr = LinearRegression()
 
liregr.fit(x_train, y_train)
print(regr.score(x_test, y_test))
# Out:
# 0.5722588120127134

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split 
import pandas as pd 

df = pd.read_csv('housing_price_dataset.csv')

threshold = df['Price'].median()

df['Class'] = df['Price'] > threshold

x = df.drop(['Price', 'Class'], axis=1)

x = pd.get_dummies(x)

y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

model = GaussianNB()
model.fit(x_train, y_train)

accuracy = model.score(x_test, y_test)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 0.8050666666666667

# %%
from sklearn.model_selection import train_test_split 
import pandas as pd 

df = pd.read_csv('housing_price_dataset.csv')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
import pandas as pd 

df = pd.read_csv('housing_price_dataset.csv')

threshold = df['Price'].median() 

df['Class'] = df['Price'] > threshold 

x = df.drop(['Price', 'Class'], axis=1)

x = pd.get_dummies(x)

y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

rf = RandomForestClassifier()
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7746

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
import pandas as pd 

df = pd.read_csv('housing_price_dataset.csv')

threshold = df['Price'].median() 

df['Class'] = df['Price'] > threshold 

x = df.drop(['Price', 'Class'], axis=1)

x = pd.get_dummies(x)

y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7606

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import pandas as pd

df = pd.read_csv('housing_price_dataset.csv')

threshold = df['Price'].median()

df['Class'] = df['Price'] > threshold

x = df.drop(['Price', 'Class'], axis=1)

x = pd.get_dummies(x)

y = df['Class']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)


knn = KNeighborsClassifier(n_neighbors=3)

cv_scores = cross_val_score(knn, x, y, cv=5, scoring='accuracy')

print(f'Cross-Validation Scores: {cv_scores}')
print(f'Mean Accuracy: {cv_scores.mean()}')
# Out:
# Cross-Validation Scores: [0.7566 0.7532 0.7628 0.7627 0.7667]
# Mean Accuracy: 0.7604000000000001

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd 

df = pd.read_csv('housing_price_dataset.csv')
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

dtc = DecisionTreeClassifier()

dtc = dtc.fit(x_train,y_train)
y_pred = dtc.predict(x_test)

print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7122

# %%
from sklearn import svm
import pandas as pd 
from sklearn import metrics


df = pd.read_csv('housing_price_dataset.csv')
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

clf = svm.SVC(kernel='linear') 
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7122

# %%
from sklearn.ensemble import GradientBoostingClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

df = pd.read_csv('housing_price_dataset.csv')

threshold = df['Price'].median()

df['Class'] = df['Price'] > threshold

x = df.drop(['Price', 'Class'], axis=1)
x = pd.get_dummies(x)
y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

grad_boost = GradientBoostingClassifier(learning_rate=0.1)

grad_boost.fit(x_train, y_train)

y_pred = grad_boost.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy : {accuracy}')
# Out:
# Accuracy : 0.8024

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8024
#               precision    recall  f1-score   support
#
#        False       0.80      0.81      0.81      7534
#         True       0.81      0.79      0.80      7466
#
#     accuracy                           0.80     15000
#    macro avg       0.80      0.80      0.80     15000
# weighted avg       0.80      0.80      0.80     15000
#
# [[6140 1394]
#  [1570 5896]]

# %%
df.shape
# Out:
# (50000, 7)

# %%
#Naive Bayes
